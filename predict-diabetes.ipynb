# %%
1. Primary Prediction (Must-Have)
    🟢 Low risk

    🟡 Pre-diabetic / At risk

    🔴 High risk (likely diabetic)

2. Secondary Predictions (High Value)
    Risk probability (0–100%) This individual has a 72% probability of developing diabetes in the next risk window

3.Feature Importance / Key Risk Drivers
    What contributes more: BMI vs Age vs Glucose?

    At what BMI does risk sharply increase?
    
    Does family history dominate lifestyle factors?
    
    Techniques:
    
    SHAP values
    
    Permutation importance
    
    Coefficients (Logistic Regression)
    
    📌 This is gold in a capstone defense.

4. Preventive & Prescriptive Intelligence (What Makes You Stand Out)
        Personalized Prevention Recommendation Engine

# %%
Problem Statement :
Build a machine learning–driven diabetes risk prediction and prevention system that classifies individuals into risk categories, identifies key contributing factors, and provides personalized, actionable lifestyle recommendations to reduce future diabetes onset.
